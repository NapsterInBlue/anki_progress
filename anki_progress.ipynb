# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from data import get_study_time
from viz import plot_trended_study_time

study_time = get_study_time()
ax = plot_trended_study_time(study_time)

# %%
from data import get_all_card_statuses_by_day
from viz import plot_card_catalog_growth

df = get_all_card_statuses_by_day()
gb = df.groupby(['date', 'status']).size().unstack().fillna(0)
plot_card_catalog_growth(gb);
